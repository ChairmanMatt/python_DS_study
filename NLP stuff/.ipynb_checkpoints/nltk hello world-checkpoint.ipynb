# %% [markdown]
# # nltk hello world
#
# ## Problems it can solve
#
# - Sentiment Analysis
# - Text Segmentation
# - Search Engine
# - Speech Recognition
# - Spam Filtering
# - etc....

# %% [markdown]
# ## nltk benefits it provide
# - tokenizing words and sentences
# - stop words
# - stemming
# - parts of speech
# - chunking
# - chinking
# - Lemmatizing
# - More...

# %%
### install  nltk
## pip install -U nltk
## nltk.download()

# %%
#Tokenizing Words and Sentences
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
EXAMPLE_TEXT = "Vonage is a great company? Do you really think so ? Mr. JD told so!! Let's believe in the best."
print(sent_tokenize(EXAMPLE_TEXT))
print(word_tokenize(EXAMPLE_TEXT))
# Out:
# ['Vonage is a great company?', 'Do you really think so ?', 'Mr. JD told so!!', "Let's believe in the best."]
# ['Vonage', 'is', 'a', 'great', 'company', '?', 'Do', 'you', 'really', 'think', 'so', '?', 'Mr.', 'JD', 'told', 'so', '!', '!', 'Let', "'s", 'believe', 'in', 'the', 'best', '.']

# %%
#Stop words
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
stop_words = set(stopwords.words('english'))
word_tokens = word_tokenize(EXAMPLE_TEXT)
filtered_stop_sen = [w for w in word_tokens if not w in stop_words]
print(word_tokens)
print(filtered_stop_sen)
# Out:
# ['Vonage', 'is', 'a', 'great', 'company', '?', 'Do', 'you', 'really', 'think', 'so', '?', 'Mr.', 'JD', 'told', 'so', '!', '!', 'Let', "'s", 'believe', 'in', 'the', 'best', '.']
# ['Vonage', 'great', 'company', '?', 'Do', 'really', 'think', '?', 'Mr.', 'JD', 'told', '!', '!', 'Let', "'s", 'believe', 'best', '.']

# %%
#Text classify
#Sentiment
import nltk
import random
from nltk.corpus import movie_reviews
from nltk.classify.scikitlearn import SklearnClassifier
from sklearn.naive_bayes import MultinomialNB,BernoulliNB
print(movie_reviews)
##create the document
documents = [(list(movie_reviews.words(fileid)),category)
             for category in movie_reviews.categories()
            for fileid in movie_reviews.fileids(category)]
#shuffle so that dataset is not biased
random.shuffle(documents)
print(documents[1])

#Find most frequent words
all_words = []
for w in movie_reviews.words():
    all_words.append(w.lower())
all_words = nltk.FreqDist(all_words)
#print(all_words.most_common(15))
word_features = list(all_words.keys())[:3000]
def find_features(document):
    words = set(document)
    features = {}
    for w in word_features:
        features[w] = (w in words)

    return features
#print((find_features(movie_reviews.words('neg/cv000_29416.txt'))))
#Find and creat featuresets
featuresets = [(find_features(rev), category) for (rev, category) in documents]
print(featuresets[0])
training_set = featuresets[:1200]
testing_set = featuresets[1200:]
classifier = nltk.NaiveBayesClassifier.train(training_set)
print("Classifier accuracy percent:",(nltk.classify.accuracy(classifier, testing_set))*100)
classifier.show_most_informative_features(15)
MNB_classifier = SklearnClassifier(MultinomialNB())
MNB_classifier.train(training_set)
print("MultinomialNB accuracy percent:",nltk.classify.accuracy(MNB_classifier, testing_set))

BNB_classifier = SklearnClassifier(BernoulliNB())
BNB_classifier.train(training_set)
print("BernoulliNB accuracy percent:",nltk.classify.accuracy(BNB_classifier, testing_set))
# Out:
# <CategorizedPlaintextCorpusReader in '/Users/bparhy/nltk_data/corpora/movie_reviews'>
# ...

# %%
from textblob.classifiers import NaiveBayesClassifier as NBC
from textblob import TextBlob
training_data = [('I am good for now','pos'),('Disconnect my phone please','neg'),
                 ('I donot like this phone!','neg'),('Thanks you saved my day','pos')]
test_data = [('I cannot wait anymore','neg'),('Thanks again!','pos'),('Ok I am good','pos'),
             ('Cannot you fix anything??','neg')]
model = NBC(training_data)
print(model.classify('You guys rock'))
print(model.classify('I dont like this anymore'))
print(model.accuracy(test_data))
# Out:
# pos
# neg
# 0.5

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
#text1.concordance('Moby')
len(set(text3))
# Out:
# 2789

# %%
text5.count('lol')/len(text5)*100
# Out:
# 1.5640968673628082

# %%
# %matplotlib inline
fdist1 = FreqDist(text1)
print(fdist1)
#sorted(fdist1.most_common(50))
fdist1.plot(50,cumulative=True)
# Out:
# <FreqDist with 19317 samples and 260819 outcomes>

# %%
V = set(text1)
long_words = [w for w in V if len(w) > 15]
print(long_words)
# Out:
# ['preternaturalness', 'comprehensiveness', 'undiscriminating', 'uncomfortableness', 'circumnavigating', 'circumnavigation', 'simultaneousness', 'indispensableness', 'Physiognomically', 'physiognomically', 'uninterpenetratingly', 'superstitiousness', 'responsibilities', 'hermaphroditical', 'subterraneousness', 'circumnavigations', 'irresistibleness', 'characteristically', 'supernaturalness', 'cannibalistically', 'indiscriminately', 'uncompromisedness', 'CIRCUMNAVIGATION', 'apprehensiveness']

# %%
fdist5 = FreqDist(text5)
sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7)
list(bigrams(['more', 'is', 'said', 'than', 'done']))
# Out:
# [('more', 'is'), ('is', 'said'), ('said', 'than'), ('than', 'done')]

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text4
# Out:
# <Text: Inaugural Address Corpus>
